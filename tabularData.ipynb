# %%
import pandas as pd
data = pd.read_csv('gapminder_gdp_oceania.csv')
data #special in jupyter to make more readable table. otherwise print(data)
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
import pandas as pd
data = pd.read_csv('gapminder_gdp_oceania.csv', index_col='country')
data #special in jupyter to make more readable table. otherwise print(data)
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
dataAmericas = pd.read_csv('gapminder_gdp_americas.csv')
dataAmericas #special in jupyter to make more readable table. otherwise print(data)
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 0   Americas            Argentina     5911.315053     6856.856212
# 1   Americas              Bolivia     2677.326347     2127.686326
# 2   Americas               Brazil     2108.944355     2487.365989
# 3   Americas               Canada    11367.161120    12489.950060
# 4   Americas                Chile     3939.978789     4315.622723
# 5   Americas             Colombia     2144.115096     2323.805581
# 6   Americas           Costa Rica     2627.009471     2990.010802
# 7   Americas                 Cuba     5586.538780     6092.174359
# 8   Americas   Dominican Republic     1397.717137     1544.402995
# 9   Americas              Ecuador     3522.110717     3780.546651
# 10  Americas          El Salvador     3048.302900     3421.523218
# 11  Americas            Guatemala     2428.237769     2617.155967
# 12  Americas                Haiti     1840.366939     1726.887882
# ...

# %%
dataAmericas.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
help (dataAmericas.head)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n=5) method of pandas.core.frame.DataFrame instance
#     Return the first `n` rows.
#
#     This function returns the first `n` rows for the object based
#     on position. It is useful for quickly testing if your object
#     has the right type of data in it.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     obj_head : same type as caller
#         The first `n` rows of the caller object.
#
#     See Also
#     --------
#     DataFrame.tail: Returns the last `n` rows.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'animal':['alligator', 'bee', 'falcon', 'lion',
#     ...                    'monkey', 'parrot', 'shark', 'whale', 'zebra']})
#     >>> df
#           animal
#     0  alligator
#     1        bee
#     2     falcon
#     3       lion
#     4     monkey
#     5     parrot
#     6      shark
#     7      whale
# ...

# %%
dataAmericas.head(3)
# Out:
#   continent    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0  Americas  Argentina     5911.315053     6856.856212     7133.166023
# 1  Americas    Bolivia     2677.326347     2127.686326     2180.972546
# 2  Americas     Brazil     2108.944355     2487.365989     3336.585802
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     8052.953021     9443.038526    10079.026740     8997.897412
# 1     2586.886053     2980.331339     3548.097832     3156.510452
# 2     3429.864357     4985.711467     6660.118654     7030.835878
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     9139.671389     9308.418710    10967.281950     8797.640716
# 1     2753.691490     2961.699694     3326.143191     3413.262690
# 2     7807.095818     6950.283021     7957.980824     8131.212843
#
#    gdpPercap_2007
# 0    12779.379640
# 1     3822.137084
# 2     9065.800825

# %%
dataAmericas.tail(3)
# Out:
#    continent        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 22  Americas  United States    13990.482080    14847.127120    16173.145860
# 23  Americas        Uruguay     5716.766744     6150.772969     5603.357717
# 24  Americas      Venezuela     7689.799761     9802.466526     8422.974165
#
#     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 22    19530.365570    21806.035940    24072.632130    25009.559140
# 23     5444.619620     5703.408898     6504.339663     6920.223051
# 24     9541.474188    10505.259660    13143.950950    11152.410110
#
#     gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 22    29884.350410    32003.932240    35767.433030    39097.099550
# 23     7452.398969     8137.004775     9230.240708     7727.002004
# 24     9883.584648    10733.926310    10165.495180     8605.047831
#
#     gdpPercap_2007
# 22     42951.65309
# 23     10611.46299
# 24     11415.80569

# %%
transposed = dataAmericas.T
transposed.to_csv('transposed.csv')

# %%
europe = pd.read_csv('gapminder_gdp_europe.csv', index_col = 'country')
europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
europe.iloc[0,0] #integer locations, loc lets you use names of rows and columns
# Out:
# 1601.056136

# %%
print(europe.loc['United Kingdom'])
# Out:
# gdpPercap_1952     9979.508487
# gdpPercap_1957    11283.177950
# gdpPercap_1962    12477.177070
# gdpPercap_1967    14142.850890
# gdpPercap_1972    15895.116410
# gdpPercap_1977    17428.748460
# gdpPercap_1982    18232.424520
# gdpPercap_1987    21664.787670
# gdpPercap_1992    22705.092540
# gdpPercap_1997    26074.531360
# gdpPercap_2002    29478.999190
# gdpPercap_2007    33203.261280
# Name: United Kingdom, dtype: float64

# %%
subset = europe.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1977']
subset
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977
# country
# Italy           8243.582340    10022.401310    12269.273780    14255.984750
# Montenegro      4649.593785     5907.850937     7778.414017     9595.929905
# Netherlands    12790.849560    15363.251360    18794.745670    21209.059200
# Norway         13450.401510    16361.876470    18965.055510    23311.349390
# Poland          5338.752143     6557.152776     8006.506993     9508.141454

# %%
mask = subset > 10000
mask
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977
# country
# Italy                 False            True            True            True
# Montenegro            False           False           False           False
# Netherlands            True            True            True            True
# Norway                 True            True            True            True
# Poland                False           False           False           False

# %%
subset[mask].describe() #analysis on data true by the mask
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977
# count        2.000000        3.000000        3.000000        3.000000
# mean     13120.625535    13915.843047    16676.358320    19592.131113
# std        466.373656     3408.589070     3817.597015     4739.277320
# min      12790.849560    10022.401310    12269.273780    14255.984750
# 25%      12955.737547    12692.826335    15532.009725    17732.521975
# 50%      13120.625535    15363.251360    18794.745670    21209.059200
# 75%      13285.513523    15862.563915    18879.900590    22260.204295
# max      13450.401510    16361.876470    18965.055510    23311.349390

# %%
import matplotlib.pyplot as plt
time = [0,1,2,3]
position = [0, 100, 200, 300]
plt.plot(time,position)
plt.xlabel('Time (h)')
plt.ylabel('Position(km)')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\rache\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
years = data.columns.str.strip('gdpPercap_')

# %%
years
# Out:
# Index(['1952', '1957', '1962', '1967', '1972', '1977', '1982', '1987', '1992',
#        '1997', '2002', '2007'],
#       dtype='object')

# %%
data.columns = years.astype(int)
plt.xkcd
# Out:
# <function matplotlib.pyplot.xkcd(scale=1, length=100, randomness=2)>

# %%
data.loc['Australia'].plot()
